# %% [markdown]
# # 1. Menentukan pertanyaan bisnis
#
# 1. Stasiun mana yang punya kadar polusi CO dan NO2 tertinggi ?
# 2. Bagaimana kadar PM10 dan PM2.5 pada Stasiun yang memiliki tingkat polusi CO tertinggi pada 1 tahun terakhir?
# 3. Bagaimana kadar PM10 dan PM2.5 pada Stasiun yang memiliki tingkat polusi NO2 tertinggi pada 1 tahun terakhir?
# 4. Bagaimana peringkat stasiun berdasarkan kadar rata-rata Particulate Matter dengan diameter 2.5 mikron dan 10 mikron dari yang terendah ke tertinggi?

# %% [markdown]
# # 2. Menyiapkan library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 3. Data Wrangling

# %% [markdown]
# ## 3.1 Gathering Data

# %% [markdown]
# Deskripsi Dataset: [Air Quality](https://drive.google.com/file/d/1RhU3gJlkteaAQfyn9XOVAz7a5o1-etgr/view)
#
# Dataset ini berisi 12  file CSV (Comma-separated Values) pada 12 stasiun yang berbeda di tahun 2013 - 2017 :
# - PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv P
# - RSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv
# - PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv

# %% [markdown]
# ### 3.1.1 Melihat isi dataset stasiun **Aotizhongxin**

# %%
df_Aotizhongxin = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Aotizhongxin_20130301-20170228.csv')
df_Aotizhongxin.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# ### 3.1.2 Melihat isi dataset stasiun **Changping**

# %%
df_Changping = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Changping_20130301-20170228.csv')
df_Changping.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# ### 3.1.3 Melihat isi dataset stasiun **Dingling**

# %%
df_Dingling = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Dingling_20130301-20170228.csv')
df_Dingling.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %% [markdown]
# ### 3.1.4 Melihat isi dataset stasiun **Dongsi**

# %%
df_Dongsi = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Dongsi_20130301-20170228.csv')
df_Dongsi.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %% [markdown]
# ### 3.1.5 Melihat isi dataset stasiun **Guanyuan**

# %%
df_Guanyuan = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Guanyuan_20130301-20170228.csv')
df_Guanyuan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %% [markdown]
# ### 3.1.6 Melihat isi dataset stasiun **Gucheng**

# %%
df_Gucheng = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Gucheng_20130301-20170228.csv')
df_Gucheng.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %% [markdown]
# ### 3.1.7 Melihat isi dataset stasiun **Huairou**

# %%
df_Huairou = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Huairou_20130301-20170228.csv')
df_Huairou.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %% [markdown]
# ### 3.1.8 Melihat isi dataset stasiun **Nongzhanguan**

# %%
df_Nongzhanguan = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Nongzhanguan_20130301-20170228.csv')
df_Nongzhanguan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %% [markdown]
# ### 3.1.9 Melihat isi dataset stasiun **Shunyi**

# %%
df_Shunyi = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Shunyi_20130301-20170228.csv')
df_Shunyi.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %% [markdown]
# ### 3.1.10 Melihat isi dataset stasiun **Tiantan**

# %%
df_Tiantan = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Tiantan_20130301-20170228.csv')
df_Tiantan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %% [markdown]
# ### 3.1.11 Melihat isi dataset stasiun **Wanliu**

# %%
df_Wanliu = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Wanliu_20130301-20170228.csv')
df_Wanliu.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %% [markdown]
# ### 3.1.12 Melihat isi dataset stasiun **Wanshouxigong**

# %%
df_Wanshouxigong = pd.read_csv('dataset\PRSA_Data_20130301-20170228\PRSA_Data_Wanshouxigong_20130301-20170228.csv')
df_Wanshouxigong.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ## 3.2 Assesing Data

# %% [markdown]
# ### 3.2.1 Pemeriksaan dataset stasiun **Aotizhongxin**

# %%
print('\n',df_Aotizhongxin.info())
print(f'Jumlah data df_Aotizhongxin yang terdapat missing value :\n{df_Aotizhongxin.isnull().sum()}')
print(f'\nJumlah data duplikat df_Aotizhongxin = {df_Aotizhongxin.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Aotizhongxin')
df_Aotizhongxin.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Aotizhongxin, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `co` sebanyak 1775 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.2 Pemeriksaan dataset stasiun **Changping**

# %%
print('\n',df_Changping.info())
print(f'Jumlah data df_Changping yang terdapat missing value :\n{df_Changping.isnull().sum()}')
print(f'\nJumlah data duplikat df_Changping = {df_Changping.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Changping')
df_Changping.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Changping, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `co` sebanyak 1521 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.3 Pemeriksaan dataset stasiun **Dingling**

# %%
print('\n',df_Dingling.info())
print(f'Jumlah data df_Dingling yang terdapat missing value :\n{df_Dingling.isnull().sum()}')
print(f'\nJumlah data duplikat df_Dingling = {df_Dingling.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Dingling')
df_Dingling.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Dingling, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `co` sebanyak 2012 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.4 Pemeriksaan dataset stasiun **Dongsi**

# %%
print('\n',df_Dongsi.info())
print(f'Jumlah data df_Dongsi yang terdapat missing value :\n{df_Dongsi.isnull().sum()}')
print(f'\nJumlah data duplikat df_Dongsi = {df_Dongsi.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Dongsi')
df_Dongsi.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Dongsi, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `CO` sebanyak 3197 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.5 Pemeriksaan dataset stasiun **Guanyuan**

# %%
print('\n',df_Guanyuan.info())
print(f'Jumlah data df_Guanyuan yang terdapat missing value :\n{df_Guanyuan.isnull().sum()}')
print(f'\nJumlah data duplikat df_Guanyuan = {df_Guanyuan.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Guanyuan')
df_Guanyuan.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Guanyua, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `CO` sebanyak 1753 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.6 Pemeriksaan dataset stasiun **Gucheng**

# %%
print('\n',df_Gucheng.info())
print(f'Jumlah data df_Gucheng yang terdapat missing value :\n{df_Gucheng.isnull().sum()}')
print(f'\nJumlah data duplikat df_Gucheng = {df_Gucheng.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Gucheng')
df_Gucheng.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Gucheng, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `CO` sebanyak 1401 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.7 Pemeriksaan dataset stasiun **Huairou**

# %%
print('\n',df_Huairou.info())
print(f'Jumlah data df_Huairou yang terdapat missing value :\n{df_Huairou.isnull().sum()}')
print(f'\nJumlah data duplikat df_Huairou = {df_Huairou.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Huairou')
df_Huairou.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Huairou, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `NO2` sebanyak 1639 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.8 Pemeriksaan dataset stasiun **Nongzhanguan**

# %%
print('\n',df_Nongzhanguan.info())
print(f'Jumlah data df_Nongzhanguan yang terdapat missing value :\n{df_Nongzhanguan.isnull().sum()}')
print(f'\nJumlah data duplikat df_Nongzhanguan = {df_Nongzhanguan.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Nongzhanguan')
df_Nongzhanguan.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Nongzhanguan, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `CO` sebanyak 1206 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.9 Pemeriksaan dataset stasiun **Shunyi**

# %%
print('\n',df_Shunyi.info())
print(f'Jumlah data df_Shunyi yang terdapat missing value :\n{df_Shunyi.isnull().sum()}')
print(f'\nJumlah data duplikat df_Shunyi = {df_Shunyi.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Shunyi')
df_Shunyi.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Shunyi, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `CO` sebanyak 2178 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.10 Pemeriksaan dataset stasiun **Tiantan**

# %%
print('\n',df_Tiantan.info())
print(f'Jumlah data df_Tiantan yang terdapat missing value :\n{df_Tiantan.isnull().sum()}')
print(f'\nJumlah data duplikat df_Tiantan = {df_Tiantan.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Tiantan')
df_Tiantan.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Tiantan, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `CO` sebanyak 1126 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.11 Pemeriksaan dataset stasiun **Wanliu**

# %%
print('\n',df_Wanliu.info())
print(f'Jumlah data df_Wanliu yang terdapat missing value :\n{df_Wanliu.isnull().sum()}')
print(f'\nJumlah data duplikat df_Wanliu = {df_Wanliu.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Wanliu')
df_Wanliu.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Wanliu, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `O3` sebanyak 2107 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ### 3.2.12 Pemeriksaan dataset stasiun **Wanshouxigong**

# %%
print('\n',df_Wanshouxigong.info())
print(f'Jumlah data df_Wanshouxigong yang terdapat missing value :\n{df_Wanshouxigong.isnull().sum()}')
print(f'\nJumlah data duplikat df_Wanshouxigong = {df_Wanshouxigong.duplicated().sum()}')
print('\nDesripsi Statistik df_df_Wanshouxigong')
df_Wanshouxigong.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
#
#  None
# ...

# %% [markdown]
# Berdasarkan pengamatan df_Wanshouxigong, dapat dilihat bahwa :
# 1. Terdapat *missing value* pada 12 kolom dengan kolom terbanyak yaitu `O3` sebanyak 1297 *missing value*
# 2. Terdapat kesalahan type data pada kolom `year` , `month`, `day` dan `hour`
# 3. Tidak Terdapat nilai yang duplikat
# 4. Tidak terdapat parameter statistik yang tidak sesuai dengan kolom atau atirbut masing-masing data dari DataFrame tersebut.

# %% [markdown]
# ## 3.3 Cleaning Data

# %% [markdown]
# ### 3.3.1 Inisialisasi DataFrames untuk Stasiun Kualitas Udara

# %%
dataframes = {
    "aotizhongxin": df_Aotizhongxin,
    "changping": df_Changping,
    "dingling": df_Dingling,
    "dongsi": df_Dongsi,
    "guanyuan": df_Guanyuan,
    "gucheng": df_Gucheng,
    "huairou": df_Huairou,
    "nongzhanguan": df_Nongzhanguan,
    "shunyi": df_Shunyi,
    "tiantan": df_Tiantan,
    "wanliu": df_Wanliu,
    "wanshouxigong": df_Wanshouxigong
}

# %% [markdown]
# ### 3.3.2 Menangani missing value

# %% [markdown]
# Dalam menangani missing value pada data timeseries digunakan metode interpolation polynomial

# %%
for location, df in dataframes.items():
    # Menggunakan interpolasi linear untuk mengisi nilai-nilai yang hilang
    df.interpolate(method='linear', inplace=True)

# %% [markdown]
# Dalam menangani missing value pada kolom `NO2` digunakan metode imputation dengan mengganti nilai null dengan nilai yang Mode(nilai yang paling sering muncul dalam suatu data) pada kolom tersebut

# %%
final_no2 = []

for location, df in dataframes.items():
    # Mengganti nilai yang hilang dengan mean
    mode_no2 = df['NO2'].mode().values[0] if not df['NO2'].mode().empty else None

    print(location, " : ", mode_no2)
    final_no2.append(mode_no2)
# Out:
# aotizhongxin  :  26.0
# changping  :  20.0
# dingling  :  2.0
# dongsi  :  20.0
# guanyuan  :  28.0
# gucheng  :  12.0
# huairou  :  2.0
# nongzhanguan  :  32.0
# shunyi  :  10.0
# tiantan  :  26.0
# wanliu  :  42.0
# wanshouxigong  :  30.0

# %% [markdown]
# Selanjutnya menginput nilai tersebut ke kolom  `NO2`

# %%
for location, df in dataframes.items():
  df['NO2'].fillna(final_no2[list(dataframes.keys()).index(location)], inplace=True)

# %% [markdown]
# ### 3.3.3. Menangani Kesalahan tipe data

# %% [markdown]
# type data pada kolom `year` , `month`, `day` dan `hour` akan diubah menjadi tipe data `datetime`

# %%
for station_name, df in dataframes.items():
    # Gabungkan kolom 'year', 'month', 'day', dan 'hour' menjadi satu kolom datetime
    df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

    # Menggunakan kolom datetime sebagai indeks
    df.set_index('datetime', inplace=True)

    # Menghapus kolom 'year', 'month', 'day', dan 'hour' dari DataFrame
    df.drop(['year', 'month', 'day', 'hour'], axis=1, inplace=True)

# %% [markdown]
# ### 3.3.4 Menghapus Kolom yang tidak digunakan

# %%
drop_list=['No','SO2','O3','TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']
for station_name, df in dataframes.items():
  df.drop(drop_list, axis=1, inplace=True)

# %% [markdown]
# ### 3.3.5 Menampilkan hasil Cleaning Data

# %%
for station_name, df in dataframes.items():
    print(f"\n\n Jumlah missing value pada stasiun {station_name} : ")
    print(f"{df.isna().sum()}")
# Out:
#  Jumlah missing value pada stasiun aotizhongxin :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
#  Jumlah missing value pada stasiun changping :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
#  Jumlah missing value pada stasiun dingling :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
#  Jumlah missing value pada stasiun dongsi :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
#  Jumlah missing value pada stasiun guanyuan :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
#  Jumlah missing value pada stasiun gucheng :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
#  Jumlah missing value pada stasiun huairou :
# PM2.5      0
# PM10       0
# NO2        0
# CO         0
# station    0
# dtype: int64
#
#
# ...

# %% [markdown]
# # 4. Exploratory Data analysis (EDA)

# %%
for station_name, df in dataframes.items():
  print(station_name, ": \n",df.describe(include='all'),'\n')
# Out:
# aotizhongxin :
#                 PM2.5          PM10           NO2            CO       station
# count   35064.000000  35064.000000  35064.000000  35064.000000         35064
# unique           NaN           NaN           NaN           NaN             1
# top              NaN           NaN           NaN           NaN  Aotizhongxin
# freq             NaN           NaN           NaN           NaN         35064
# mean       82.540623    110.210033     59.074106   1264.692405           NaN
# std        81.956401     95.262531     37.000918   1239.411826           NaN
# min         3.000000      2.000000      2.000000    100.000000           NaN
# 25%        22.000000     38.000000     30.000000    500.000000           NaN
# 50%        58.000000     87.000000     53.000000    900.000000           NaN
# 75%       114.000000    154.000000     81.000000   1500.000000           NaN
# max       898.000000    984.000000    290.000000  10000.000000           NaN
#
# changping :
# ...

# %%
df_Aotizhongxin.hist(bins=15, figsize=(10, 7))
# Out:
# array([[<AxesSubplot: title={'center': 'PM2.5'}>,
#         <AxesSubplot: title={'center': 'PM10'}>],
#        [<AxesSubplot: title={'center': 'NO2'}>,
#         <AxesSubplot: title={'center': 'CO'}>]], dtype=object)

# %% [markdown]
# Berdasarkan hasil pengamatan plot atau grafik histogram untuk df_Aotizhongxin di atas, dapat dilihat bahwa:
# Kolom PM 2.5, PM10, NO2 dan CO memiliki bentuk histogram yang yang right-skewed (positive skewness).

# %%
plt.figure(figsize=(5, 4))
correlationMatrix = df_Aotizhongxin.corr().round(2)

sns.heatmap(
    data=correlationMatrix,
    vmin=-1,
    vmax=1,
    cmap='coolwarm',
    annot=True,
    linewidths=0.5
)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5492\1467937035.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlationMatrix = df_Aotizhongxin.corr().round(2)
# <AxesSubplot: >

# %% [markdown]
# Dapat dilihat pada grafik atau diagram heatmap di atas memiliki range atau rentang dari angka 1.0 hingga -1.0 dengan keterangan sebagai berikut,
#
# = Jika semakin mendekati 1, maka korelasi antar fitur numerik semakin kuat bernilai positif.
#
# - Jika semakin mendekati 0, maka korelasi antar fitur numerik semakin rendah.
#
# - Jika semakin mendekati -1, maka korelasi antar fitur numerik semakin kuat bernilai negatif.
#
# - Jika korelasi bernilai positif, berarti nilai kedua fitur numerik cenderung meningkat bersama-sama.
#
# - Jika korelasi bernilai negatif, berarti nilai salah satu fitur numerik cenderung meningkat ketika nilai fitur numerik yang lain menurun.
#
# Berdasarkan hasil pengamatan grafik atau diagram heatmap correlation matrix untuk masing-masing df_Aotizhongxin, dapat dilihat bahwa dataset Aotizhongxin memiliki korelasi yang kuat bernilai positif pada keempat kolom tersebut

# %% [markdown]
# Menggabungkan dataset menjadi 1 dataframe

# %%
air_quality_df = df_Aotizhongxin

skip_first = True
for location, df in dataframes.items():
  if skip_first:
        skip_first = False
        continue  
  air_quality_df = pd.merge(
      left=air_quality_df,
      right=df,
      how="left",
      left_on="datetime",
      right_on="datetime",
      suffixes=("", f"_{location}")
      )

# %%
air_quality_df = air_quality_df.rename(columns= {
    'PM2.5': 'PM2.5_aotizhongxin',
    'PM10': 'PM10_aotizhongxin',
    'NO2': 'NO2_aotizhongxin', 
    'CO': 'CO_aotizhongxin',
    'station': 'station_aotizhongxin'
})


air_quality_df = air_quality_df.drop(columns=[col for col in air_quality_df.columns if col.startswith('station_')])

# %%
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 48 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PM2.5_aotizhongxin   35064 non-null  float64
#  1   PM10_aotizhongxin    35064 non-null  float64
#  2   NO2_aotizhongxin     35064 non-null  float64
#  3   CO_aotizhongxin      35064 non-null  float64
#  4   PM2.5_changping      35064 non-null  float64
#  5   PM10_changping       35064 non-null  float64
#  6   NO2_changping        35064 non-null  float64
#  7   CO_changping         35064 non-null  float64
#  8   PM2.5_dingling       35064 non-null  float64
#  9   PM10_dingling        35064 non-null  float64
#  10  NO2_dingling         35064 non-null  float64
#  11  CO_dingling          35064 non-null  float64
#  12  PM2.5_dongsi         35064 non-null  float64
#  13  PM10_dongsi          35064 non-null  float64
# ...

# %% [markdown]
# # 5. Visualization & Explanatory Analysis

# %%
def calculate_mean_df(df, parameter):
    columns = [col for col in df.columns if col.startswith(f'{parameter}_')]
    mean_df = df[columns].copy()
    mean_df = mean_df.describe().loc['mean']
    mean_df = mean_df.reset_index()
    mean_df = mean_df.rename(columns={'index': 'station', 'mean': f'{parameter} mean'})
    mean_df['station'] = mean_df['station'].str.replace(f'{parameter}_', '', regex=False)
    return mean_df

mean_CO_df = calculate_mean_df(air_quality_df, 'CO')
mean_NO2_df = calculate_mean_df(air_quality_df, 'NO2')

result_df = pd.merge(mean_CO_df, mean_NO2_df, on='station')

# %%
result_df.head()
# Out:
#         station      CO mean   NO2 mean
# 0  aotizhongxin  1264.692405  59.074106
# 1     changping  1156.990246  44.206153
# 2      dingling   925.111838  27.303589
# 3        dongsi  1331.913045  53.953078
# 4      guanyuan  1258.327045  58.139298

# %%
sorted_mean_NO2_df = result_df.sort_values(by="NO2 mean", ascending=False)
print(sorted_mean_NO2_df.to_string(index=False))
# Out:
#       station     CO mean  NO2 mean
#        wanliu 1328.761180 65.668418
#  aotizhongxin 1264.692405 59.074106
#      guanyuan 1258.327045 58.139298
#  nongzhanguan 1327.767611 58.095053
#       gucheng 1338.100060 55.826307
# wanshouxigong 1373.618569 55.495402
#        dongsi 1331.913045 53.953078
#       tiantan 1305.333262 53.258828
#     changping 1156.990246 44.206153
#        shunyi 1197.904660 44.094695
#       huairou 1019.671871 32.077275
#      dingling  925.111838 27.303589

# %%
sorted_mean_CO_df = result_df.sort_values(by="CO mean", ascending=False)
print(sorted_mean_CO_df.to_string(index=False))
# Out:
#       station     CO mean  NO2 mean
# wanshouxigong 1373.618569 55.495402
#       gucheng 1338.100060 55.826307
#        dongsi 1331.913045 53.953078
#        wanliu 1328.761180 65.668418
#  nongzhanguan 1327.767611 58.095053
#       tiantan 1305.333262 53.258828
#  aotizhongxin 1264.692405 59.074106
#      guanyuan 1258.327045 58.139298
#        shunyi 1197.904660 44.094695
#     changping 1156.990246 44.206153
#       huairou 1019.671871 32.077275
#      dingling  925.111838 27.303589

# %% [markdown]
# ## 5.1 Stasiun mana yang punya kadar polusi CO dan NO2 tertinggi ?

# %%
# Set style
sns.set(style="whitegrid")

# Data Preparation
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# Bar Plot for CO Mean
sns.barplot(x="CO mean", y="station", data=sorted_mean_CO_df.head(), ax=ax[0], palette=["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"])
ax[0].set_ylabel("Station", fontsize=13)
ax[0].set_xlabel("Average Carbon Monoxide (CO)", fontsize=13)
ax[0].tick_params(axis='both', labelsize=15)

# Bar Plot for NO2 Mean
sns.barplot(x="NO2 mean", y="station", data=sorted_mean_NO2_df.head(), ax=ax[1], palette=["#7ACACB", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"])
ax[1].set_ylabel("Station", fontsize=13)
ax[1].set_xlabel("Average Nitrogen Dioxide (NO2)", fontsize=13)
ax[1].tick_params(axis='both', labelsize=15)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()

# Overall Title
plt.suptitle("Highest Average Carbon Monoxide (CO) and Nitrogen Dioxide (NO2) at the Station", fontsize=20, weight='bold')
plt.tight_layout()


plt.show()

# %% [markdown]
# ## 5.2 Bagaimana kadar PM10 dan PM2.5 pada Stasiun yang memiliki tingkat polusi CO tertinggi pada 1 tahun terakhir?

# %% [markdown]
# Berdasarkan visualisasi di atas diketahui bahwa station yang memiliki tingkat polusi CO tertinggi adalah Wanshouxigong

# %%
# Membuat dataframe baru yang berisi Data Timeseries Air Quality di Stasiun wanshouxigong
Wanshouxigong_timeseries_df = df_Wanshouxigong.copy()
Wanshouxigong_timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PM2.5    35064 non-null  float64
#  1   PM10     35064 non-null  float64
#  2   NO2      35064 non-null  float64
#  3   CO       35064 non-null  float64
#  4   station  35064 non-null  object
# dtypes: float64(4), object(1)
# memory usage: 1.6+ MB

# %%
Wanshouxigong_timeseries_df.head()
# Out:
#                      PM2.5  PM10   NO2     CO        station
# datetime
# 2013-03-01 00:00:00    9.0   9.0  17.0  200.0  Wanshouxigong
# 2013-03-01 01:00:00   11.0  11.0  14.0  200.0  Wanshouxigong
# 2013-03-01 02:00:00    8.0   8.0  16.0  200.0  Wanshouxigong
# 2013-03-01 03:00:00    8.0   8.0  16.0  250.0  Wanshouxigong
# 2013-03-01 04:00:00    8.0   8.0  12.0  300.0  Wanshouxigong

# %%
Wanshouxigong_monthly_df = Wanshouxigong_timeseries_df.reset_index()
Wanshouxigong_monthly_df = Wanshouxigong_monthly_df.resample(rule='M', on='datetime').agg({
    "PM10": "mean",
    "PM2.5": "mean"
})
Wanshouxigong_monthly_df.index = Wanshouxigong_monthly_df.index.strftime('%Y %B')
Wanshouxigong_monthly_df = Wanshouxigong_monthly_df.reset_index()

# %%
Wanshouxigong_monthly_df.head()
# Out:
#      datetime        PM10       PM2.5
# 0  2013 March  130.193548  106.698925
# 1  2013 April   93.930556   78.903472
# 2    2013 May  129.033602   81.770161
# 3   2013 June  118.386806  105.869444
# 4   2013 July   73.727151   68.150538

# %%
# Create a line chart
last_1_year = Wanshouxigong_monthly_df.tail(12)
plt.figure(figsize=(12, 5))

# Line chart for PM10
plt.plot(
    last_1_year['datetime'],
    last_1_year['PM10'],
    marker='o',
    linestyle='-',
    color='r',
    label='PM10'
)

# Add label for the highest value of PM10
max_PM10_date = last_1_year.loc[last_1_year['PM10'].idxmax()]['datetime']
max_PM10_value = round(last_1_year['PM10'].max())
plt.text(max_PM10_date, max_PM10_value, f'{max_PM10_value}', ha='left', va='bottom', color='r', fontsize=12)

# Line chart for PM2.5
plt.plot(
    last_1_year['datetime'],
    last_1_year['PM2.5'],
    marker='o',
    linestyle='-',
    color='b',
    label='PM2.5'
)

# Add label for the highest value of PM2.5
max_PM25_date = last_1_year.loc[last_1_year['PM2.5'].idxmax()]['datetime']
max_PM25_value = round(last_1_year['PM2.5'].max())
plt.text(max_PM25_date, max_PM25_value, f'{max_PM25_value}', ha='left', va='bottom', color='b', fontsize=13)

plt.title('Average Monthly PM 2.5 and 10 at Station with the Highest CO (Wanshouxigong) Levels Last 12 Months')
plt.xticks(fontsize=10, rotation=45)
plt.xlabel('Date')
plt.yticks(fontsize=10)
plt.ylabel('PM Level')
plt.legend()  # Add legend for better interpretation
plt.grid(True, linestyle='--', linewidth=0.5, which='both', color='gray')

# Show the line chart
plt.show()

# %% [markdown]
# ## 5.3 Bagaimana kadar PM10 dan PM2.5 pada Stasiun yang memiliki tingkat polusi NO2 tertinggi pada 1 tahun terakhir?

# %% [markdown]
# Berdasarkan visualisasi di atas diketahui bahwa station yang memiliki tingkat polusi NO2 tertinggi adalah Wanliu

# %%
# Membuat dataframe baru yang berisi Data Timeseries Air Quality di Stasiun Wanliu

wanliu_timeseries_df = df_Wanliu.copy()
wanliu_timeseries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35064 entries, 2013-03-01 00:00:00 to 2017-02-28 23:00:00
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PM2.5    35064 non-null  float64
#  1   PM10     35064 non-null  float64
#  2   NO2      35064 non-null  float64
#  3   CO       35064 non-null  float64
#  4   station  35064 non-null  object
# dtypes: float64(4), object(1)
# memory usage: 1.6+ MB

# %%
wanliu_timeseries_df.head()
# Out:
#                      PM2.5  PM10   NO2     CO station
# datetime
# 2013-03-01 00:00:00    8.0   8.0  28.0  400.0  Wanliu
# 2013-03-01 01:00:00    9.0   9.0  28.0  400.0  Wanliu
# 2013-03-01 02:00:00    3.0   6.0  19.0  400.0  Wanliu
# 2013-03-01 03:00:00   11.0  30.0  14.0  350.0  Wanliu
# 2013-03-01 04:00:00    3.0  13.0  15.5  300.0  Wanliu

# %%
wanliu_monthly_df = wanliu_timeseries_df.reset_index()
wanliu_monthly_df = wanliu_monthly_df.resample(rule='M', on='datetime').agg({
    "PM10": "mean",
    "PM2.5": "mean"
})
wanliu_monthly_df.index = wanliu_monthly_df.index.strftime('%Y %B')
wanliu_monthly_df = wanliu_monthly_df.reset_index()

# %%
wanliu_monthly_df.head()
# Out:
#      datetime        PM10       PM2.5
# 0  2013 March  147.760753  110.272849
# 1  2013 April  108.544444   66.541667
# 2    2013 May  129.813172   92.978495
# 3   2013 June  113.602778  119.980556
# 4   2013 July   80.051747   75.714382

# %%
# Create a line chart
last_1_year = wanliu_monthly_df.tail(12)
plt.figure(figsize=(12, 5))

# Line chart for PM10
plt.plot(
    last_1_year['datetime'],
    last_1_year['PM10'],
    marker='o',
    linestyle='-',
    color='r',
    label='PM10'
)

# Add label for the highest value of PM10
max_PM10_date = last_1_year.loc[last_1_year['PM10'].idxmax()]['datetime']
max_PM10_value = round(last_1_year['PM10'].max())
plt.text(max_PM10_date, max_PM10_value, f'{max_PM10_value}', ha='left', va='bottom', color='r', fontsize=14)

# Line chart for PM2.5
plt.plot(
    last_1_year['datetime'],
    last_1_year['PM2.5'],
    marker='o',
    linestyle='-',
    color='b',
    label='PM2.5'
)

# Add label for the highest value of PM2.5
max_PM25_date = last_1_year.loc[last_1_year['PM2.5'].idxmax()]['datetime']
max_PM25_value = round(last_1_year['PM2.5'].max())
plt.text(max_PM25_date, max_PM25_value, f'{max_PM25_value}', ha='left', va='bottom', color='b', fontsize=14)

plt.title('Average Monthly PM 2.5 and 10 at Station with the Highest NO2 (Wanliu) Levels Last 12 Months')
plt.xticks(fontsize=10, rotation=45)
plt.xlabel('Date')
plt.yticks(fontsize=10)
plt.ylabel('PM Level')
plt.legend()  # Add legend for better interpretation
plt.grid(True, linestyle='--', linewidth=0.5, which='both', color='gray')

# Show the line chart
plt.show()

# %% [markdown]
# ## 5.4 Bagaimana peringkat stasiun berdasarkan kadar rata-rata Particulate Matter dengan diameter 2.5 mikron dan 10 mikron dari yang terendah ke tertinggi?

# %%
mean_PM25_df = calculate_mean_df(air_quality_df, 'PM2.5')
mean_PM10_df = calculate_mean_df(air_quality_df, 'PM10')

PM_df = pd.merge(mean_PM25_df, mean_PM10_df, on='station')

# %%
PM_df.head()
# Out:
#         station  PM2.5 mean   PM10 mean
# 0  aotizhongxin   82.540623  110.210033
# 1     changping   70.986438   94.788575
# 2      dingling   66.845557   84.113713
# 3        dongsi   86.144243  110.347617
# 4      guanyuan   82.897522  109.372349

# %%
sorted_mean_PM25_df = PM_df.sort_values(by="PM2.5 mean", ascending=True)
print(sorted_mean_PM25_df.to_string(index=False))
# Out:
#       station  PM2.5 mean  PM10 mean
#      dingling   66.845557  84.113713
#       huairou   69.501747  92.422670
#     changping   70.986438  94.788575
#        shunyi   79.437962  99.271936
#       tiantan   82.033097 106.537076
#  aotizhongxin   82.540623 110.210033
#      guanyuan   82.897522 109.372349
#        wanliu   83.467612 110.707858
#       gucheng   84.074802 119.261567
# wanshouxigong   85.067548 112.505795
#  nongzhanguan   85.079472 109.384022
#        dongsi   86.144243 110.347617

# %%
sorted_mean_PM10_df = PM_df.sort_values(by="PM10 mean", ascending=True)
print(sorted_mean_PM10_df.to_string(index=False))
# Out:
#       station  PM2.5 mean  PM10 mean
#      dingling   66.845557  84.113713
#       huairou   69.501747  92.422670
#     changping   70.986438  94.788575
#        shunyi   79.437962  99.271936
#       tiantan   82.033097 106.537076
#      guanyuan   82.897522 109.372349
#  nongzhanguan   85.079472 109.384022
#  aotizhongxin   82.540623 110.210033
#        dongsi   86.144243 110.347617
#        wanliu   83.467612 110.707858
# wanshouxigong   85.067548 112.505795
#       gucheng   84.074802 119.261567

# %%
# Set style
sns.set(style="whitegrid")

# Data Preparation
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))

# Bar Plot for CO Mean
sns.barplot(x="PM2.5 mean", y="station", data=sorted_mean_PM25_df, ax=ax[0],palette="Reds_r")
ax[0].set_ylabel("Station", fontsize=13)
ax[0].set_xlabel("Average PM 2.5", fontsize=13,weight='bold')
ax[0].tick_params(axis='both', labelsize=15)

# Bar Plot for NO2 Mean
sns.barplot(x="PM10 mean", y="station", data=sorted_mean_PM10_df, ax=ax[1],palette="Blues_r")
ax[1].set_ylabel("Station", fontsize=13)
ax[1].set_xlabel("Average PM 10", fontsize=13,weight='bold',)
ax[1].tick_params(axis='both', labelsize=15)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()

# Overall Title
plt.suptitle("Order of Average Particulate Matter 2.5 mikron and 10 mikron at the Station", fontsize=20, weight='bold')
plt.tight_layout()


plt.show()

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# 1. Stasiun mana yang punya kadar polusi CO dan NO2 tertinggi ? \
#     `Dari hasil visualisasi data menggunakan bar chart pada bagian 5.1, diketahui bahwa station dengan kadar polusi rata-rata Karbon Monoksida (CO) tertinggi tertinggi adalah Wanshouxigong dengan nilai rata-rata yaitu 1373,6 .Sedangkan station dengan kadar polusi rata-rata Nitrogen dioxida (NO2) tertinggi adalah station Wanliu dengan nilai rata-rata yaitu 65,6  `
#
# 2. Bagaimana kadar PM10 dan PM2.5 pada Stasiun yang memiliki tingkat polusi CO tertinggi pada 1 tahun terakhir?
#
#     `Berdasarkan jawaban pertanyaan 1 dapat diketahui bahwa station yang memiliki tingkat polusi CO tertinggi adalah station Wanshouxigong. Dari hasil visualisasi data menggunakan line chart pada bagian 5.2, diketahui bahwa data 1 tahun terakhir pada kadar PM 10 dan PM 2.5 cenderung fluktuatif. Kadar terendah terjadi pada bulan Agustus 2016 dan Puncaknya pada Desember 2016. Kenaikan kadar PM 10 dan PM 2.5 terjadi dari Agustus-Desember 2016. Namun, kembali menurun pada Januari-Februari 2017 `
#
# 3. Bagaimana kadar PM10 dan PM2.5 pada Stasiun yang memiliki tingkat polusi NO2 tertinggi pada 1 tahun terakhir?
#
#     `Dari jawaban pertanyaan 1 dapat diketahui bahwa station yang memiliki tingkat polusi NO2 tertinggi adalah station Wanliu. Berdasarkan hasil visualisasi data menggunakan line chart pada bagian 5.3, diketahui bahwa data 1 tahun terakhir pada kadar PM 10 dan PM 2.5 cenderung fluktuatif.Kenaikan kadar PM 10 dan PM 2.5 terjadi dari Agustus-Desember 2016. Namun, kembali menurun pada Januari-Februari 2017.Kadar terendah terjadi pada bulan Agustus 2016 dan Puncaknya pada Desember 2016.  `
#
# 4. Bagaimana peringkat stasiun berdasarkan kadar rata-rata Particulate Matter dengan diameter 2.5 mikron dan 10 mikron dari yang terendah ke tertinggi?
#
#     `Dari hasil visualisasi data menggunakan bar chart pada bagian 5.4. Berikut adalah peringkat kadar rata-rata Particulate Matter dari terendah ke tertinggi :`
#     - **Kadar PM 2.5**:
#       1. dingling
#       2. huairou
#       3. changping
#       4. shunyi
#       5. tiantan
#       6. aotizhongxin
#       7. guanyuan
#       8. wanliu
#       9. gucheng
#       10. wanshouxigong
#       11. nongzhanguan
#       12. dongsi
#
#     - **Kadar PM 10**:
#         1. dingling
#         2. huairou
#         3. changping
#         4. shunyi
#         5. tiantan
#         6. guanyuan
#         7. nongzhanguan
#         8. aotizhongxin
#         9. dongsi
#         10. wanliu
#         11. wanshouxigong
#         12. gucheng

# %% [markdown]
# # 7.Export Data

# %% [markdown]
# Dari hasil pertanyaan bisnis dan conlusion maka data yang akan di export untuk keperluan visualisasi di streamlit yaitu:
# 1. Data `Air Quality` pada 12 statiun
# 2. Data `Air Quality` station dengan Kadar CO tertinggi
# 3. Data `Air Quality` station dengan Kadar NO2 tertinggi

# %%
air_quality_df = air_quality_df.reset_index()
HighestCO_timeseries_df = Wanshouxigong_timeseries_df.reset_index()
HighestNO2_timeseries_df = wanliu_timeseries_df.reset_index()

# %% [markdown]
# Menyimpan data hasil analisis ke dalam csv

# %%
air_quality_df.to_csv(r"dataset\air_quality_df.csv", index=False)
HighestCO_timeseries_df.to_csv(r"dataset\HighestCO_timeseries_df.csv", index=False)
HighestNO2_timeseries_df.to_csv(r"dataset\HighestNO2_timeseries_df.csv", index=False)
